# %% [markdown]
# <a href="https://colab.research.google.com/github/jordanmsouza/Hacka_Pos_Fiap/blob/main/Projeto_Hackathon_1IADT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Conectando ao Google Drive para salvar modelo e carregar datasets

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Criar um atalho para os arquivos no Drive (opcional)
# !ln -s /content/drive/MyDrive/HackaFiap/ yolov5_drive

# %% [markdown]
# Instalando dependências e clonando o repositório do YOLOv5, um modelo Open-Source que utiliza deep learning para detectar objetos em imagens

# %%
# Instalar dependências necessárias
# !pip install -q ultralytics

# Clonar o repositório do YOLOv5
# !git clone https://github.com/ultralytics/yolov5.git
# %cd yolov5
# !pip install -r requirements.txt
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.
# /content/yolov5
# ...

# %% [markdown]
# Download do dataset no Kaggle

# %%
# !pip install -q kaggle
# !mkdir ~/.kaggle
# !cp /content/drive/MyDrive/HackaFiap/kaggle.json ~/.kaggle/  # Substitua com o caminho do arquivo kaggle.json
# !chmod 600 ~/.kaggle/kaggle.json
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %% [markdown]
# Baixe o dataset

# %%
# !kaggle datasets download -d raghavnanjappan/weapon-dataset-for-yolov5
# !unzip weapon-dataset-for-yolov5.zip -d /content/drive/MyDrive/HackaFiap/dataset/
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/drive/MyDrive/HackaFiap/dataset/dataset/dataset/images/train/4052.jpg
#   inflating: /content/drive/MyDrive/HackaFiap/dataset/dataset/dataset/images/train/4053.jpg
#   inflating: /content/drive/MyDrive/HackaFiap/dataset/dataset/dataset/images/train/4054.jpg
#   inflating: /content/drive/MyDrive/HackaFiap/dataset/dataset/dataset/images/train/4055.jpg
#   inflating: /content/drive/MyDrive/HackaFiap/dataset/dataset/dataset/images/train/4056.jpg
#   inflating: /content/drive/MyDrive/HackaFiap/dataset/dataset/dataset/images/train/4057.jpg
#   inflating: /content/drive/MyDrive/HackaFiap/dataset/dataset/dataset/images/train/4058.jpg
#   inflating: /content/drive/MyDrive/HackaFiap/dataset/dataset/dataset/images/train/4059.jpg
#   inflating: /content/drive/MyDrive/HackaFiap/dataset/dataset/dataset/images/train/406.jpg
#   inflating: /content/drive/MyDrive/HackaFiap/dataset/dataset/dataset/images/train/4060.jpg
# ...

# %% [markdown]
# Criação e confiugração do arquivo `dataset.yaml`

# %%
# %%writefile dataset.yaml
# train: /content/dataset/images/train
# val: /content/dataset/images/val
# nc: 3  # Número de classes
# names: ['knife', 'scissors', 'gun']
# Out:
# Writing dataset.yaml

# %% [markdown]
# Treinando o modelo YOLOv5

# %%
# !python train.py --img 640 --batch 16 --epochs 50 --data /content/dataset/dataset.yaml --weights yolov5s.pt
# Out:
# Streaming output truncated to the last 5000 lines.
#       37/49       4.4G    0.03037     0.0127    0.00107         43        640:  93% 232/250 [02:01<00:11,  1.58it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       37/49       4.4G     0.0304    0.01271   0.001069         36        640:  93% 233/250 [02:01<00:08,  1.93it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       37/49       4.4G    0.03039    0.01269   0.001068         32        640:  94% 234/250 [02:02<00:08,  1.90it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
# ...

# %% [markdown]
# Avaliar o desempenho do modelo

# %%
# !python val.py --weights runs/train/exp/weights/best.pt --data dataset.yaml
# Out:
# val: data=dataset.yaml, weights=['runs/train/exp/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-397-gde62f93c Python-3.11.11 torch-2.5.1+cu121 CPU
#
# Traceback (most recent call last):
#   File "/content/yolov5/val.py", line 604, in <module>
#     main(opt)
#   File "/content/yolov5/val.py", line 575, in main
#     run(**vars(opt))
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/_contextlib.py", line 116, in decorate_context
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/content/yolov5/val.py", line 270, in run
#     model = DetectMultiBackend(weights, device=device, dnn=dnn, data=data, fp16=half)
# ...

# %% [markdown]
# Upload do arquivo de vídeo para testar o modelo

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --source /content/video_knife_detection.mp4 --img 640 --conf 0.4

# %% [markdown]
# Salve os resultados no Google Drive

# %%
# !cp -r runs/train/ /content/drive/MyDrive/
